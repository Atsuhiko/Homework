# %% [markdown]
# ## 宿題 5：Pandas (3) 目的変数と説明変数の DataFrame 作成
# 「iris_original.csv」から、目的変数だけの「X」と 解答の 「ｙ」を Pandas の機能を使って４種類の作成しなさい。
# （ヒント① 宿題 3-3 の後の「おまけ」を参照する。ヒント② loc[], iloc[]を使用する。）

# %%
import pandas as pd

# %%
df = pd.read_csv("iris_original.csv")

# %%
df.head()
# Out:
#     a1   a2   a3   a4    id        label
# 0  5.1  3.5  1.4  0.2  id_1  Iris-setosa
# 1  4.9  3.0  1.4  0.2  id_2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  id_3  Iris-setosa
# 3  4.6  3.1  1.5  0.2  id_4  Iris-setosa
# 4  5.0  3.6  1.4  0.2  id_5  Iris-setosa

# %%
X1 = df.drop(["label","id"], axis=1)
X1.head()
# Out:
#     a1   a2   a3   a4
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
y1 = pd.DataFrame(df["label"])
y1.head()
# Out:
#          label
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
X2 = df[["a1","a2","a3","a4"]]
X2.head()
# Out:
#     a1   a2   a3   a4
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
y2 = pd.DataFrame(df.label)
y2.head()
# Out:
#          label
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
X3 = df.loc[:,"a1":"a4"]
X3.head()
# Out:
#     a1   a2   a3   a4
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
y3 = pd.DataFrame(df.loc[:,"label"])
y3.head()
# Out:
#          label
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
X4 = df.iloc[:,0:4]
X4.head()
# Out:
#     a1   a2   a3   a4
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
y4 = pd.DataFrame(df.iloc[:,5])
y4.head()
# Out:
#          label
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa
